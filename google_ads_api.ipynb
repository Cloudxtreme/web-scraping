# %%
#import libraries
import os
import sys
import json
import numpy as np
import urllib2
import urllib
import time

#HDFS cli data fetching
from hdfs import Config
import pandas as pd
import Queue
from hdfs.ext.avro import AvroReader, AvroWriter
from hdfs.ext.dataframe import read_dataframe, write_dataframe

#need to set default encoding or foreign languages wont work
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

client = Config().get_client('holdem') #Get a client

# %%
job_translations = {
"de_DE": "stellen",
"ru_RU": "jobs",
"it_IT": "offerte-di-lavoro",
"pl_PL": "jobs",
"sv_SE": "jobs",
"da_DK": "jobs",
"tr_TR": "jobs",
"pt_BR": "jobs",
"ja_JP": "jobs",
"fr_FR": "emplois",
"cs_CZ": "jobs",
"fi_FI": "jobs",
"ko_KR": "jobs",
"es_ES": "empleos",
"zh_CN": "职位",
"no_NO": "jobs",
"ar_AE": "jobs",
"nl_NL": "jobs",
"en_US": "jobs"
}

# %%
country_mappings = {
"de_DE": [2276],
"ru_RU": [2643],
"it_IT": [2380],
"pl_PL": [2616],
"sv_SE": [2752],
"da_DK": [2208],
"tr_TR": [2792],
#"pt_BR": [2076, 2620], #brazil and portugal
"pt_BR": [2076], #brazil only
"ja_JP": [2392],
"fr_FR": [2250],
"cs_CZ": [2203],
"fi_FI": [2246],
"ko_KR": [2410],
"es_ES": [2724],
"zh_CN": [2156],
"no_NO": [2578],
"ar_AE": [2784],
"nl_NL": [2528],
#"en_US": [2840,2826,2036,2702,2356,2124]
"en_US": [2840] #us only
}

# %%
schema = {
      'doc': 'Google Ads Volume Metrics',
      'name': 'googleads',
      'fields': [
        {'name': 'id', 'type': 'string'},
        {'name': 'search_keyword', 'type': 'string'}, 
        {'name': 'volume', 'type': 'string'},
        {'name': 'location', 'type': 'string'},
        {'name': 'keyword', 'type': 'string'}
      ],
      'type': 'record'
}

# %%
pandas_schema = ['id'
                 ,'search_keyword'
                 ,'volume'
                 ,'location'
                 ,'keyword']

# %%
#read in the file of keywords
scoreFile = '/data/derived/standardization/taxonomy/title/5/5.1.0/titles.avro'  #File path on HDFS
df3 = read_dataframe(client, scoreFile)
df3.head(10)
# Out:
#   acronyms                                            aliases blacklistStatus  \
# 0       {}         {u'en_US': [u'consultant sap technology']}         ALLOWED
# 1       {}                                                 {}         ALLOWED
# 2       {}             {u'en_US': [u'branch manager office']}         ALLOWED
# 3       {}           {u'en_US': [u'manager services shared']}         ALLOWED
# 4       {}  {u'en_US': [u'business development operations ...         ALLOWED
# 5       {}  {u'ru_RU': [u'руководитель отдела разработки с...         ALLOWED
# 6       {}  {u'ru_RU': [u'Командующий', u'начальник'], u'f...         ALLOWED
# 7       {}          {u'en_US': [u'hardware manager project']}         ALLOWED
# 8       {}                                                 {}         ALLOWED
# 9       {}  {u'en_US': [u'advanced application business co...         ALLOWED
#
#          dimensions displayNames functions granularity     id isOccupation  \
# 0   {u'roleId': 82}           {}        []       TITLE  12005         True
# 1    {u'roleId': 2}           {}        []       TITLE  21391         True
# 2              None           {}        []       TITLE   9380        False
# 3              None           {}        []       TITLE   6914        False
# 4  {u'roleId': 114}           {}        []       TITLE  10484         True
# 5              None           {}        []       TITLE   5139        False
# 6              None           {}        []       TITLE   8904        False
# 7    {u'roleId': 4}           {}        []       TITLE  21327         True
# 8  {u'roleId': 167}           {}        []       TITLE  11928         True
# 9              None           {}        []       TITLE  14729        False
#
#   isRole                              machineTranslatedName misspellings  \
# 0  False  {u'ru_RU': u'сок техническии консультант', u'r...           {}
# 1  False  {u'ru_RU': u'диетическое менеджер', u'ro_RO': ...           {}
# 2  False  {u'ro_RO': u'manager de sucursala', u'fr_FR': ...           {}
# 3  False  {u'pt_BR': u'gerente de servicos compartilhado...           {}
# 4  False  {u'ru_RU': u'вице президент операции по развит...           {}
# 5   True  {u'pt_BR': u'gerente de frequencia de radio', ...           {}
# 6   True  {u'ru_RU': u'Командующий', u'da_DK': u'kommand...           {}
# 7  False  {u'ru_RU': u'менеджер аппаратных проект', u'ro...           {}
# 8  False  {u'ru_RU': u'сердечно сосудистои специалист', ...           {}
# 9  False  {u'ru_RU': u'старшии сок консультант расширенн...           {}
#
#                                                names  preferredTitle  \
# 0  {u'ru_RU': u'Консультант по SAP-технологиям', ...             NaN
# 1  {u'ru_RU': u'Менеджер-диетолог', u'ar_AE': u'م...             NaN
# 2               {u'en_US': u'Branch Office Manager'}             NaN
# 3  {u'ru_RU': u'Менеджер по общекорпоративным сер...             NaN
# 4  {u'ru_RU': u'Вице-президент по управлению и ра...             NaN
# 5  {u'ru_RU': u'Диспетчер радиосвязи', u'ar_AE': ...             NaN
# 6  {u'ru_RU': u'Комендант', u'ar_AE': u'آمر', u'f...             NaN
# 7  {u'ru_RU': u'Руководитель проекта по установке...             NaN
# 8  {u'ru_RU': u'Специалист в области сердечнососу...             NaN
# 9  {u'en_US': u'Senior Sap Advanced Business Appl...             NaN
#
#    seniority  status              superTitles  \
# 0        4.0  ACTIVE  [urn:li:superTitle:441]
# 1        5.0  ACTIVE  [urn:li:superTitle:317]
# 2        4.0  ACTIVE  [urn:li:superTitle:223]
# 3        5.0  ACTIVE  [urn:li:superTitle:245]
# 4        7.0  ACTIVE  [urn:li:superTitle:469]
# 5        5.0  ACTIVE  [urn:li:superTitle:333]
# 6        5.0  ACTIVE  [urn:li:superTitle:442]
# 7        4.0  ACTIVE  [urn:li:superTitle:483]
# 8        3.0  ACTIVE  [urn:li:superTitle:620]
# 9        4.0  ACTIVE  [urn:li:superTitle:441]
#
#                                            vague wikipediaUrl
# 0  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 1  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 2  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 3  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 4  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 5  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 6  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 7  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 8  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 9  {u'isVerified': True, u'vaguenessLevel': 0.0}         None

# %%
df3.head(10)
# Out:
#   acronyms                                            aliases blacklistStatus  \
# 0       {}         {u'en_US': [u'consultant sap technology']}         ALLOWED
# 1       {}                                                 {}         ALLOWED
# 2       {}             {u'en_US': [u'branch manager office']}         ALLOWED
# 3       {}           {u'en_US': [u'manager services shared']}         ALLOWED
# 4       {}  {u'en_US': [u'business development operations ...         ALLOWED
# 5       {}  {u'ru_RU': [u'руководитель отдела разработки с...         ALLOWED
# 6       {}  {u'ru_RU': [u'Командующий', u'начальник'], u'f...         ALLOWED
# 7       {}          {u'en_US': [u'hardware manager project']}         ALLOWED
# 8       {}                                                 {}         ALLOWED
# 9       {}  {u'en_US': [u'advanced application business co...         ALLOWED
#
#          dimensions displayNames functions granularity     id isOccupation  \
# 0   {u'roleId': 82}           {}        []       TITLE  12005         True
# 1    {u'roleId': 2}           {}        []       TITLE  21391         True
# 2              None           {}        []       TITLE   9380        False
# 3              None           {}        []       TITLE   6914        False
# 4  {u'roleId': 114}           {}        []       TITLE  10484         True
# 5              None           {}        []       TITLE   5139        False
# 6              None           {}        []       TITLE   8904        False
# 7    {u'roleId': 4}           {}        []       TITLE  21327         True
# 8  {u'roleId': 167}           {}        []       TITLE  11928         True
# 9              None           {}        []       TITLE  14729        False
#
#   isRole                              machineTranslatedName misspellings  \
# 0  False  {u'ru_RU': u'сок техническии консультант', u'r...           {}
# 1  False  {u'ru_RU': u'диетическое менеджер', u'ro_RO': ...           {}
# 2  False  {u'ro_RO': u'manager de sucursala', u'fr_FR': ...           {}
# 3  False  {u'pt_BR': u'gerente de servicos compartilhado...           {}
# 4  False  {u'ru_RU': u'вице президент операции по развит...           {}
# 5   True  {u'pt_BR': u'gerente de frequencia de radio', ...           {}
# 6   True  {u'ru_RU': u'Командующий', u'da_DK': u'kommand...           {}
# 7  False  {u'ru_RU': u'менеджер аппаратных проект', u'ro...           {}
# 8  False  {u'ru_RU': u'сердечно сосудистои специалист', ...           {}
# 9  False  {u'ru_RU': u'старшии сок консультант расширенн...           {}
#
#                                                names  preferredTitle  \
# 0  {u'ru_RU': u'Консультант по SAP-технологиям', ...             NaN
# 1  {u'ru_RU': u'Менеджер-диетолог', u'ar_AE': u'م...             NaN
# 2               {u'en_US': u'Branch Office Manager'}             NaN
# 3  {u'ru_RU': u'Менеджер по общекорпоративным сер...             NaN
# 4  {u'ru_RU': u'Вице-президент по управлению и ра...             NaN
# 5  {u'ru_RU': u'Диспетчер радиосвязи', u'ar_AE': ...             NaN
# 6  {u'ru_RU': u'Комендант', u'ar_AE': u'آمر', u'f...             NaN
# 7  {u'ru_RU': u'Руководитель проекта по установке...             NaN
# 8  {u'ru_RU': u'Специалист в области сердечнососу...             NaN
# 9  {u'en_US': u'Senior Sap Advanced Business Appl...             NaN
#
#    seniority  status              superTitles  \
# 0        4.0  ACTIVE  [urn:li:superTitle:441]
# 1        5.0  ACTIVE  [urn:li:superTitle:317]
# 2        4.0  ACTIVE  [urn:li:superTitle:223]
# 3        5.0  ACTIVE  [urn:li:superTitle:245]
# 4        7.0  ACTIVE  [urn:li:superTitle:469]
# 5        5.0  ACTIVE  [urn:li:superTitle:333]
# 6        5.0  ACTIVE  [urn:li:superTitle:442]
# 7        4.0  ACTIVE  [urn:li:superTitle:483]
# 8        3.0  ACTIVE  [urn:li:superTitle:620]
# 9        4.0  ACTIVE  [urn:li:superTitle:441]
#
#                                            vague wikipediaUrl
# 0  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 1  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 2  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 3  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 4  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 5  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 6  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 7  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 8  {u'isVerified': True, u'vaguenessLevel': 0.0}         None
# 9  {u'isVerified': True, u'vaguenessLevel': 0.0}         None

# %%
len(df3)
# Out:
# 24701

# %%
keyword_dict = df3.iloc[3]['names']
keyword_dict
# Out:
# {u'ar_AE': u'\u0645\u062f\u064a\u0631 \u062e\u062f\u0645\u0627\u062a \u0645\u0634\u062a\u0631\u0643\u0629',
#  u'cs_CZ': u'Mana\u017eer sd\xedlen\xfdch slu\u017eeb',
#  u'da_DK': u'Chef, delte tjenester',
#  u'de_DE': u'Shared Services Manager',
#  u'en_US': u'Shared Services Manager',
#  u'es_ES': u'Director de servicios compartidos',
#  u'fi_FI': u'Jaettujen palvelujen p\xe4\xe4llikk\xf6',
#  u'fr_FR': u'Responsable des services partag\xe9s',
#  u'it_IT': u'Responsabile servizi condivisi',
#  u'ja_JP': u'\u5171\u6709\u30b5\u30fc\u30d3\u30b9\u30de\u30cd\u30fc\u30b8\u30e3\u30fc',
#  u'ko_KR': u'\uacf5\uc720 \uc11c\ube44\uc2a4 \uad00\ub9ac\uc790',
#  u'nl_NL': u'Manager gedeelde services',
#  u'no_NO': u'Leder for delte tjenester',
#  u'pl_PL': u'Kierownik ds. us\u0142ug wsp\xf3lnych',
#  u'pt_BR': u'Gerente de servi\xe7os compartilhados',
#  u'ru_RU': u'\u041c\u0435\u043d\u0435\u0434\u0436\u0435\u0440 \u043f\u043e \u043e\u0431\u0449\u0435\u043a\u043e\u0440\u043f\u043e\u0440\u0430\u0442\u0438\u0432\u043d\u044b\u043c \u0441\u0435\u0440\u0432\u0438\u0441\u0430\u043c',
#  u'sv_SE': u'Ansvarig f\xf6r delade tj\xe4nster',
#  u'tr_TR': u'Ortak Hizmetler M\xfcd\xfcr\xfc',
#  u'zh_CN': u'\u5171\u4eab\u670d\u52a1\u7ecf\u7406'}

# %%
myid = df3.iloc[1]['id']
myid
# Out:
# 21391

# %%
len(keyword_dict)
# Out:
# 19

# %%
keyword_keys = df3.iloc[1]['names'].keys()
keywords = df3.iloc[1]['names'].values()
keyword_keys
# Out:
# [u'ru_RU',
#  u'ar_AE',
#  u'fr_FR',
#  u'pt_BR',
#  u'zh_CN',
#  u'fi_FI',
#  u'da_DK',
#  u'ko_KR',
#  u'it_IT',
#  u'sv_SE',
#  u'no_NO',
#  u'ja_JP',
#  u'nl_NL',
#  u'en_US',
#  u'tr_TR',
#  u'de_DE',
#  u'pl_PL',
#  u'cs_CZ',
#  u'es_ES']

# %%
def build_search_keywords(keyword_dict):
    """
    Creates the list of keywords to be passed to the google ads api.  
    We need to append the translated word for "jobs" at the end of each of the keywords
    
    params:
        keyword_dict: dictionary of keywords, just a single keyword
    
    input: dictionary of languages and keywords, just a string keyword
    output: list of keywords with translated "job" appended to the end
    
    """
    if type(keyword_dict) == dict:
        keyword_keys = keyword_dict.keys();
        search_keywords = [];
        
        for i in keyword_keys:
            mykeyword = keyword_dict[i].encode('utf8').strip();
            job_trans = job_translations[str(i)];
            search_keywords.append(mykeyword + ' ' + job_trans);
        return search_keywords
    else:
        mykeyword = keyword_dict;
        mykeyword = mykeyword.encode('utf8').strip();
        job_trans = job_translations[country];
        search_keyword = mykeyword + ' ' + job_trans;
        
        return search_keyword

if __name__ == '__main__':
    keyword_dict = df3.iloc[1]['names'];
    search_keywords = build_search_keywords(keyword_dict);

# %%
type({}) == dict
# Out:
# True

# %%
search_keywords
# Out:
# ['\xd0\x9c\xd0\xb5\xd0\xbd\xd0\xb5\xd0\xb4\xd0\xb6\xd0\xb5\xd1\x80-\xd0\xb4\xd0\xb8\xd0\xb5\xd1\x82\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3 jobs',
#  '\xd9\x85\xd8\xaf\xd9\x8a\xd8\xb1 \xd8\xa3\xd8\xb8\xd9\x85\xd8\xa9 \xd8\xba\xd8\xb0\xd8\xa7\xd8\xa6\xd9\x8a\xd8\xa9 jobs',
#  'Manager di\xc3\xa9t\xc3\xa9tiste emplois',
#  'Gerente de nutri\xc3\xa7\xc3\xa3o jobs',
#  '\xe8\x86\xb3\xe9\xa3\x9f\xe7\xbb\x8f\xe7\x90\x86 \xe8\x81\x8c\xe4\xbd\x8d',
#  'Ravitsemusp\xc3\xa4\xc3\xa4llikk\xc3\xb6 jobs',
#  'Kostchef jobs',
#  '\xec\x8b\x9d\xec\x9d\xb4\xec\x9a\x94\xeb\xb2\x95 \xea\xb4\x80\xeb\xa6\xac\xec\x9e\x90 jobs',
#  'Responsabile dietista offerte-di-lavoro',
#  'Dietistansvarig jobs',
#  'Leder for kosthold jobs',
#  '\xe9\xa3\x9f\xe4\xba\x8b\xe7\x99\x82\xe6\xb3\x95\xe7\xae\xa1\xe7\x90\x86\xe8\x80\x85 jobs',
#  'Dieetmanager jobs',
#  'Dietary Manager jobs',
#  'Beslenme Y\xc3\xb6neticisi jobs',
#  'Ern\xc3\xa4hrungsmanager stellen',
#  'Kierownik ds. dietetycznych jobs',
#  'Mana\xc5\xbeer stravov\xc3\xa1n\xc3\xad jobs',
#  'Director de nutrici\xc3\xb3n empleos']

# %%
def add_to_dataframe(google_api_result, keyword_dict, myid, country, dataframe):
    """
    Adds the google api result and original keyword to the pandas dataframe
    
    input: 
    output: 
    """
    keywords = keyword_dict.values()
    
    for i in range(len(google_api_result)):
        mydata = [str(myid)] + google_api_result[i] + [country] + [keywords[i]]
        dataframe = dataframe.append(pd.DataFrame([tuple(mydata)], columns = pandas_schema))
    return dataframe

# %%
def add_to_dataframe2(google_api_result, keyword, myid, country, dataframe):
    """
    Adds the google api result and original keyword to the pandas dataframe
    
    input: 
    output: 
    """
    
    mydata = [str(myid)] + google_api_result + [country] + [keyword]
    dataframe = dataframe.append(pd.DataFrame([tuple(mydata)], columns = pandas_schema))
    return dataframe

# %%
"""
This retrieves keywords that are related to a given keyword.
The LoadFromStorage method is pulling credentials and properties from a
"googleads.yaml" file. By default, it looks for this file in your home
directory. For more information, see the "Caching authentication information"
section of our README.
"""

from googleads import adwords
PAGE_SIZE = 700

def main(client, mykeywords, country_code):
  # List for storing the results.
  mylist = []

  # Initialize appropriate service.
  targeting_idea_service = client.GetService(
      'TargetingIdeaService', version='v201609')

  # Construct selector object and retrieve related keywords.
  offset = 0
  selector = {
      'searchParameters': [
          {
              'xsi_type': 'RelatedToQuerySearchParameter',
              'queries': mykeywords
          },
          {
              # Network search parameter (optional)
              'xsi_type': 'NetworkSearchParameter',
              'networkSetting': {
                  'targetGoogleSearch': True,
                  'targetSearchNetwork': False,
                  'targetContentNetwork': False,
                  'targetPartnerSearchNetwork': False
              }
          },
          {
              'xsi_type': 'LocationSearchParameter',
              'locations': [{'id': country_code}]
              #'locations': [{'id': [2076, 2620] }]
              
          }
      ],
      'ideaType': 'KEYWORD',
      'requestType': 'STATS',#STATS or IDEAS
      'requestedAttributeTypes': ['KEYWORD_TEXT', 'SEARCH_VOLUME'], #['KEYWORD_TEXT', 'SEARCH_VOLUME','CATEGORY_PRODUCTS_AND_SERVICES'],
      'paging': {
          'startIndex': str(offset),
          'numberResults': str(PAGE_SIZE)
      }
  }

  more_pages = True
  while more_pages:
    page = targeting_idea_service.get(selector)

    # Display results.
    if 'entries' in page:
      for result in page['entries']:
        attributes = {}
        for attribute in result['data']:
          attributes[attribute['key']] = getattr(attribute['value'], 'value','0')
#         print ('Keyword with \'%s\' text and average monthly search volume '
#                '\'%s\' was found with Products and Services categories: %s.'
#                % (attributes['KEYWORD_TEXT'],
#                   attributes['SEARCH_VOLUME'],
#                   attributes['CATEGORY_PRODUCTS_AND_SERVICES']))
        
        mylist.append([str(attributes['KEYWORD_TEXT']), str(attributes['SEARCH_VOLUME'])])
        
    else:
      print 'No related keywords were found.'
    offset += PAGE_SIZE
    selector['paging']['startIndex'] = str(offset)
    more_pages = offset < int(page['totalNumEntries'])
    
    return mylist

# %%
country_mappings[country]
# Out:
# [2840, 2826, 2036, 2702, 2356, 2124]

# %%
if __name__ == '__main__':
    """Driver for google ads API requests, version 2
    
    This one sends the request 700 keywords at a time for one language/location . 
    This might be a better strategy because of the limits of the google ads API.
    
    Also has keyword deduplication built in
    """
    #initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage();

    #initialize pandas dataframe
    mydataframe = pd.DataFrame(columns = pandas_schema);

    #iterate over all the countries
    for i in job_translations.keys():
        country = i
        #country = 'es_ES'
        myids = []
        keywords = []
        request_keywords = []

        count = 0;

        num_iter = len(df3)

        for i in range(num_iter):
        #for i in range(1400):
        #for i in range(24500, len(df3)):
            try:
                myid        = df3.iloc[i]['id'];
                keyword     = df3.iloc[i]['names'][country];
                myids.append(myid);

                keywords.append(keyword);
                request_keywords.append(build_search_keywords(keyword)); #append the translated word for jobs
                
                count += 1;
            except:
                pass

            if count % 700 == 0:
                #first, remove duplicates
                keywords, myids, request_keywords = remove_duplicates(keywords, myids, request_keywords)

                if len(request_keywords) == 0:
                    pass
                else:
                    google_api_results = main(adwords_client, request_keywords, country_mappings[country]);
                    for i in range(len(google_api_results)):
                        api_result = google_api_results[i]
                        keyword = keywords[i]
                        myid = myids[i]
                        mydataframe = add_to_dataframe2(api_result, keyword, myid, country, mydataframe)

                    myids = []
                    keywords = []
                    request_keywords = []
                    time.sleep(2)

            if count == num_iter:
                google_api_results = main(adwords_client, request_keywords, country_mappings[country]);

                for i in range(len(google_api_results)):
                    api_result = google_api_results[i]
                    keyword = keywords[i]
                    myid = myids[i]

                    mydataframe = add_to_dataframe2(api_result, keyword, myid, country, mydataframe)

# %%
class RemoveDuplicates(object):
    def __init__(self):
        pass
    
    @staticmethod
    def list_duplicates(seq):
      seen = set()
      seen_add = seen.add
      # adds all elements it doesn't know yet to seen and all other to seen_twice
      seen_twice = set( x for x in seq if x in seen or seen_add(x) )
      # turn the set into a list (as requested)
      return list(seen_twice)

    @staticmethod
    def remove_duplicates(keywords, ids, request_keywords):
        mydups = RemoveDuplicates.list_duplicates(keywords)

        #dictionary to keep track of times duplicate are seen.
        dup_count = {}
        for i in mydups:
            dup_count[i] = 0

        for i in range(len(keywords)):
            keyword = keywords[i]
            if keyword in mydups:
                dup_count[keyword] += 1
                if dup_count[keyword] > 1:
                    keywords[i] = 'remove'
                    ids[i] = 'remove'
                    request_keywords[i] = 'remove'

        while 'remove' in keywords: 
            keywords.remove('remove')
        while 'remove' in ids:
            ids.remove('remove')
        while 'remove' in request_keywords:
            request_keywords.remove('remove')

        return keywords, ids, request_keywords

# %%
list_duplicates(keywords)
# Out:
# [u'Encargado de facturaci\xf3n',
#  u'Ingeniero civil',
#  u'Consultor de energ\xeda solar',
#  u'Instructor de equitaci\xf3n',
#  u'Instructor de tiro con armas de fuego',
#  u'Oficial de centro de detenci\xf3n',
#  u'Instructor de aquagym',
#  u'Instructor de actividades al aire libre',
#  u'Instructor de gimnasia']

# %%
keywords
# Out:
# []

# %%
remove_duplicates(keywords)

# %%
len(request_keywords)
request_keywords
# Out:
# ['Consultor de tecnolog\xc3\xada SAP empleos',
#  'Director de nutrici\xc3\xb3n empleos',
#  'Director de servicios compartidos empleos',
#  'Vicepresidente de desarrollo de operaciones empresariales empleos',
#  'Director de RF empleos',
#  'Comandante empleos',
#  'Director de proyectos de hardware empleos',
#  'Especialista cardiovascular empleos',
#  'Jefe de ejecuci\xc3\xb3n de operaciones empleos',
#  'Mentor empleos',
#  'Coordinador de prestaci\xc3\xb3n de servicios empleos',
#  'Director general de inversiones empleos',
#  'Gerente de especialidad empleos',
#  'Especialista en desarrollo empleos',
#  'Jefe profesional de tienda empleos',
#  'Jefe de fletes empleos',
#  'Ingeniero de puesta en servicio empleos',
#  'Administrador de datos empleos',
#  'Supervisor cl\xc3\xadnico empleos',
#  'Ejecutivo de asistencia al cliente empleos',
#  'Gerente general de finanzas empleos',
#  'Arquitecto t\xc3\xa9cnico jefe empleos',
#  'Gerente de soporte t\xc3\xa9cnico de TI empleos',
#  'Jefe de fiscalidad empleos',
#  'Director de hardware empleos',
#  'Consultor de Java empleos',
#  'Recaudador de impuestos empleos',
#  'Jefe de cadena de suministro de clientes empleos',
#  'Operador de protecci\xc3\xb3n civil empleos',
#  'Decano acad\xc3\xa9mico empleos',
#  'Consultor comercial de servicios tecnol\xc3\xb3gicos de comunicaci\xc3\xb3n de informaci\xc3\xb3n empleos',
#  'Director de control de planificaci\xc3\xb3n empleos',
#  'Supervisor de front-end empleos',
#  'Redactor de estilo empleos',
#  'Agente de compra empleos',
#  'Director de desarrollo comercial de recursos humanos empleos',
#  'Consultor de ventas minoristas empleos',
#  'Ingeniero de sistemas de aseguramiento de la calidad empleos',
#  'Vicepresidente ejecutivo de ventas empleos',
#  'Administrador de exportaci\xc3\xb3n empleos',
#  'Ingeniero de servicio de pruebas empleos',
#  'Jefe de ventas internacionales empleos',
#  'Productor ejecutivo empleos',
#  'M\xc3\xbasica empleos',
#  'Consultor de mercado empleos',
#  'Becario en estudios empleos',
#  'Director de marketing comercial empleos',
#  'Supervisor de desarrollo y formaci\xc3\xb3n empleos',
#  'Supervisor de servicios de campo empleos',
#  'Aprendiz de administraci\xc3\xb3n de marca empleos',
#  'Especialista en CRM empleos',
#  'Radioterapeuta empleos',
#  'Director de investigaci\xc3\xb3n de marketing empleos',
#  'Director de marketing nacional empleos',
#  'Esteticista empleos',
#  'Analista de relaciones empleos',
#  'Odontolog\xc3\xada empleos',
#  'Ingeniero de dispositivos empleos',
#  'Director de residencia de graduados empleos',
#  'Especialista en derivados empleos',
#  'Director general de operaciones financieras empleos',
#  'Experto en desarrollo empleos',
#  'Contable comercial empleos',
#  'Auxiliar de relaciones con los medios empleos',
#  'Director de admisiones de graduados empleos',
#  'Empleado empleos',
#  'Director de programas del sistema empleos',
#  'Ingeniero de riesgos empleos',
#  'Personal de investigaci\xc3\xb3n y desarrollo empleos',
#  'Consultor de sistemas de informaci\xc3\xb3n para administraci\xc3\xb3n empleos',
#  'Instructor de esqu\xc3\xad empleos',
#  'Soporte a usuarios en centro de asistencia empleos',
#  'Ge\xc3\xb3logo de desarrollo empleos',
#  'Alcalde empleos',
#  'Director de gesti\xc3\xb3n de canal empleos',
#  'Coordinador de liquidaciones empleos',
#  'L\xc3\xadder de tareas empleos',
#  'Director de arte empleos',
#  'Analista de seguridad de SAP empleos',
#  'Due\xc3\xb1o de franquicia empleos',
#  'Jefe de unidad empleos',
#  'Representante de ventas especiales empleos',
#  'Gem\xc3\xb3logo empleos',
#  'Herrero empleos',
#  'Tercer ingeniero empleos',
#  'Productor multimedia empleos',
#  'Director de formaci\xc3\xb3n y desarrollo empleos',
#  'Asesor de productos empleos',
#  'Cerrajero empleos',
#  'Ingeniero de facturaci\xc3\xb3n empleos',
#  'Vicepresidente de cuentas clave empleos',
#  'Director de operaciones de sistemas empleos',
#  'Supervisor de trabajo social empleos',
#  'Director regional de ventas empleos',
#  'Tripulaci\xc3\xb3n de vuelo empleos',
#  'Supervisor de ingenier\xc3\xada de dise\xc3\xb1o empleos',
#  'Especialista en encuestas empleos',
#  'Nutricionista empleos',
#  'Ejecutivo de ventas de aplicaciones empleos',
#  'Director de teatro empleos',
#  'Director de cuentas interactivas empleos',
#  'Secretario de sucursal empleos',
#  'Director de farmacolog\xc3\xada empleos',
#  'Auxiliar de marca empleos',
#  'Abogado de propiedad intelectual empleos',
#  'Ingeniero de dise\xc3\xb1o e investigaci\xc3\xb3n empleos',
#  'Programador anal\xc3\xadtico empleos',
#  'Analista de LAN empleos',
#  'Ingeniero de servicios t\xc3\xa9cnicos empleos',
#  'Director de soporte a usuarios empleos',
#  'Qu\xc3\xadmico forense empleos',
#  'Director de sistemas empresariales empleos',
#  'Especialista en imagen empleos',
#  'Director de desarrollo empresarial y marketing empleos',
#  'Vicepresidente comercial empleos',
#  'Director de ventas y marketing de desarrollo de empresas empleos',
#  'Recepcionista empleos',
#  'Jefe de tesorer\xc3\xada empleos',
#  'Administraci\xc3\xb3n red empleos',
#  'Director de desarrollo empresarial y tecnol\xc3\xb3gico empleos',
#  'Visualizador empleos',
#  'Log\xc3\xadstica de abastecimiento empleos',
#  'Ingeniero de normativas empleos',
#  'Visitador m\xc3\xa9dico empleos',
#  'Plantador de iglesias empleos',
#  'Contable fiscal empleos',
#  'Administrador de seguridad de TI empleos',
#  'Consultor de formaci\xc3\xb3n y desarrollo empleos',
#  'Redactor de dise\xc3\xb1o empleos',
#  'Locutor de radio empleos',
#  'Director de gesti\xc3\xb3n de casos empleos',
#  'Coordinador de emergencias empleos',
#  'Ventas de seguros empleos',
#  'Miembro del consejo editorial empleos',
#  'Coordinador de investigaciones cl\xc3\xadnicas empleos',
#  'Director de inventario empleos',
#  'Jefe del departamento de compras empleos',
#  'Estudios de coordinaci\xc3\xb3n empleos',
#  'Ingeniero de dise\xc3\xb1o de hardware empleos',
#  'Jefe de nuevos negocios empleos',
#  'Empresa de software empleos',
#  'Director de nuevas tecnolog\xc3\xadas empleos',
#  'Ventas marketing y relaciones p\xc3\xbablicas empleos',
#  'Gerente de control de costes empleos',
#  'Socio de finanzas corporativas empleos',
#  'Ejecutivo de cuentas de RR. HH. empleos',
#  'Director de automatizaci\xc3\xb3n empleos',
#  'Coordinador de alquileres empleos',
#  'Controlador de programa empleos',
#  'Director de operaciones de servicios empleos',
#  'Trabajador social cl\xc3\xadnico empleos',
#  'Auxiliar de curador empleos',
#  'Cient\xc3\xadfico de servicio t\xc3\xa9cnico empleos',
#  'Empaquetador empleos',
#  'Administrativo de control de inventario empleos',
#  'Director de relaciones con empresas de telefon\xc3\xada empleos',
#  'Director de educaci\xc3\xb3n empleos',
#  'Representante de promociones empleos',
#  'Comerciante empleos',
#  'Asociaciones estrat\xc3\xa9gicas empleos',
#  'M\xc3\xbasico de estudio de grabaci\xc3\xb3n empleos',
#  'Administrativo contable empleos',
#  'Ciencias empleos',
#  'Analista de salud p\xc3\xbablica empleos',
#  'Asesor financiero empleos',
#  'Becario del departamento de comunicaci\xc3\xb3n empleos',
#  'Director de desarrollo de audiencias empleos',
#  'Jefe de consultor\xc3\xada empleos',
#  'T\xc3\xa9cnico de soporte empleos',
#  'Director de operaciones de planta empleos',
#  'Consultor de SAP MM empleos',
#  'Formaci\xc3\xb3n empresarial empleos',
#  'Administrador de red de sistemas de tecnolog\xc3\xada de la informaci\xc3\xb3n empleos',
#  'Director de ventas de servicios alimentarios empleos',
#  'Ingeniero de datos empleos',
#  'Comandante de pelot\xc3\xb3n empleos',
#  'Jefe de guardia empleos',
#  'Director de marketing para clientes empleos',
#  'Artista de iluminaci\xc3\xb3n empleos',
#  'Productor de imprenta empleos',
#  'Consultor de intercambio electr\xc3\xb3nico de datos empleos',
#  'Director de ventas institucionales empleos',
#  'Consultor de dise\xc3\xb1o de sistemas empleos',
#  'Operador tur\xc3\xadstico empleos',
#  'Oficial de fuerzas de superficie empleos',
#  'Director de desarrollo empleos',
#  'Secretario t\xc3\xa9cnico empleos',
#  'Jefe de planificaci\xc3\xb3n y previsi\xc3\xb3n empleos',
#  'Gerente de divisi\xc3\xb3n de TI empleos',
#  'Supervisor de radiodifusi\xc3\xb3n empleos',
#  'T\xc3\xa9cnico de control de red empleos',
#  'Director de banca privada empleos',
#  'Administrador de cursos empleos',
#  'Director de compilaci\xc3\xb3n empleos',
#  'Psic\xc3\xb3metra empleos',
#  'Encargado de mantenimiento empleos',
#  'Asesor de sostenibilidad empleos',
#  'Ingeniero de procesos de fabricaci\xc3\xb3n empleos',
#  'Especialista de rehabilitaci\xc3\xb3n empleos',
#  'Asesor de ventas de valores empleos',
#  'Coordinador de unidad sanitaria empleos',
#  'Redactor cient\xc3\xadfico empleos',
#  'Director de ventas para flotas empleos',
#  'Director de ventas de circulaci\xc3\xb3n empleos',
#  'Profesional de apoyo directo empleos',
#  'DBA de aplicaciones de Oracle empleos',
#  'Jefe de comunicaci\xc3\xb3n interna empleos',
#  'Becario de adquisiciones empleos',
#  'Productor asociado empleos',
#  'Supervisor fiscal empleos',
#  'Auxiliar de producci\xc3\xb3n empleos',
#  'Vicepresidente de propiedad intelectual empleos',
#  'Director comercial empleos',
#  'Becario de desarrollo de productos empleos',
#  'Representante de cr\xc3\xa9dito empleos',
#  'Instructor de ventas empleos',
#  'Responsable de selecci\xc3\xb3n de personal de recursos humanos empleos',
#  'Director de servicios avanzados empleos',
#  'Consultor de seguridad, salud ocupacional y medioambiente empleos',
#  'Perito de construcci\xc3\xb3n empleos',
#  'Asesor de viviendas de obra nueva empleos',
#  'Redactor de discursos empleos',
#  'Auxiliar pedag\xc3\xb3gico empleos',
#  'Vicepresidente de prestaci\xc3\xb3n de soluciones empleos',
#  'Docente a tiempo parcial empleos',
#  'Supervisor de ventas minoristas empleos',
#  'Investigador social empleos',
#  'Jefe de gesti\xc3\xb3n de procesos empleos',
#  'Director de ventas de afiliaci\xc3\xb3n empleos',
#  'Gerente de piscina empleos',
#  'Ejecutivo regional empleos',
#  'Consultor de selecci\xc3\xb3n de personal de recursos humanos empleos',
#  'Periodista financiero empleos',
#  'Director de arte interactivo empleos',
#  'Director del departamento de TI empleos',
#  'Director de servicios m\xc3\xa9dicos empleos',
#  'Coordinador de medios de marketing empleos',
#  'Qu\xc3\xadmico empleos',
#  'Asesor de servicios estudiantiles empleos',
#  'Administrador de producci\xc3\xb3n empleos',
#  'Miembro de la mesa de redacci\xc3\xb3n empleos',
#  'Jefe de control de calidad empleos',
#  'Becario en centro universitario empleos',
#  'Editor de c\xc3\xa1mara empleos',
#  'Planificaci\xc3\xb3n empleos',
#  'Empleado de investigaci\xc3\xb3n empleos',
#  'Inspector de bomberos empleos',
#  'Coordinador de productos empleos',
#  'Ejecutivo administrativo de recursos humanos empleos',
#  'Consultor de cambios empleos',
#  'Encargado administrativo de recursos humanos empleos',
#  'Auxiliar de centro empleos',
#  'Administrador de servicios laborales empleos',
#  'Representante de asistencia de servicios empleos',
#  'Responsable de front office empleos',
#  'Representante de cuentas del servicio de atenci\xc3\xb3n al cliente empleos',
#  'Representante de ventas al por menor empleos',
#  'Dise\xc3\xb1o de interacci\xc3\xb3n empleos',
#  'Decano empleos',
#  'Instructor de voz empleos',
#  'Desarrollador de PeopleSoft empleos',
#  'Auxiliar del ministerio empleos',
#  'Ingeniero de ventas de exportaci\xc3\xb3n empleos',
#  'Jefe de contabilidad financiera empleos',
#  'Auxiliar creativo empleos',
#  'Director de programas federales empleos',
#  'Miembro principal del personal t\xc3\xa9cnico empleos',
#  'Director de proyectos de software empleos',
#  'Tecn\xc3\xb3logo cardiovascular empleos',
#  'Director de financiaci\xc3\xb3n estructurada empleos',
#  'Ayudante de biblioteca empleos',
#  'Estimador comercial empleos',
#  'Amo de casa empleos',
#  'Cadena de suministro log\xc3\xadstica empleos',
#  'Jefe art\xc3\xadstico empleos',
#  'Asistente personal jur\xc3\xaddico empleos',
#  'Asesor de planificaci\xc3\xb3n empleos',
#  'Director medioambiental empleos',
#  'Profesional de salud mental empleos',
#  'Supervisor de recogida de datos empleos',
#  'Controlador de tesorer\xc3\xada empleos',
#  'Operador de control empleos',
#  'Jefe de planificaci\xc3\xb3n empleos',
#  'Coordinador de proyectos de ventas empleos',
#  'Auxiliar de programaci\xc3\xb3n empleos',
#  'Operador de control num\xc3\xa9rico computerizado empleos',
#  'Operario de perforadora empleos',
#  'Responsable de panel empleos',
#  'Responsable de planificaci\xc3\xb3n de productos empleos',
#  'Especialista en formaci\xc3\xb3n de ventas empleos',
#  'Agente de servicios de hu\xc3\xa9spedes empleos',
#  'Administrador de servicios de red empleos',
#  'Ejecutivo de servicio al negocio empleos',
#  'Montaje empleos',
#  'Especialista en l\xc3\xadnea empleos',
#  'Asistente del jefe de personal empleos',
#  'Director de administraci\xc3\xb3n empresarial empleos',
#  'Auxiliar documentalista empleos',
#  'Administrador de sistemas de TI empleos',
#  'Director jur\xc3\xaddico empleos',
#  'Consultor de nuevos medios empleos',
#  'Relaciones con inversores empleos',
#  'Aparcacoches empleos',
#  'T\xc3\xa9cnico comercial empleos',
#  'Director de sistemas de negocio de tecnolog\xc3\xada de la informaci\xc3\xb3n empleos',
#  'Fotoperiodista empleos',
#  'Director de operaciones de seguridad empleos',
#  'Contable de gesti\xc3\xb3n empleos',
#  'Asesor del consejo empleos',
#  'Director de operaciones de clientes empleos',
#  'Director de auditor\xc3\xada de tecnolog\xc3\xada de la informaci\xc3\xb3n empleos',
#  'Asociado fiscal empleos',
#  'Director de servicios de calidad empleos',
#  'Director del grupo de asistencia empleos',
#  'Ejecutivo de ventas de publicidad empleos',
#  'Jefe de formaci\xc3\xb3n y calidad empleos',
#  'Fot\xc3\xb3grafo deportivo empleos',
#  'Director de cuentas personales empleos',
#  'Director del centro de dise\xc3\xb1o empleos',
#  'Director de ventas industriales empleos',
#  'Jefe de ingenier\xc3\xada de instalaciones empleos',
#  'Ejecutivo de servicios y soluciones empleos',
#  'Escuela de negocios empleos',
#  'Director de proyecto del grupo empleos',
#  'Coordinador de tesorer\xc3\xada empleos',
#  'Ingeniero de oficina t\xc3\xa9cnica empleos',
#  'Auxiliar de gesti\xc3\xb3n de ventas empleos',
#  'Desarrollador web php empleos',
#  'Director de investigaci\xc3\xb3n de proyectos cl\xc3\xadnicos empleos',
#  'Estudiante de m\xc3\xa1ster cient\xc3\xadfico empleos',
#  'Dibujante de arquitectura empleos',
#  'Responsable de TI empleos',
#  'T\xc3\xa9cnico de n\xc3\xb3minas empleos',
#  'Director de asuntos gubernamentales empleos',
#  'Director de parque empleos',
#  'Gerente de financiaci\xc3\xb3n comercial empleos',
#  'Director de asuntos normativos empleos',
#  'Responsable de viviendas empleos',
#  'Coordinador comercial empleos',
#  'Supervisor de operaciones de venta empleos',
#  'Auxiliar de ventas de publicidad empleos',
#  'Jefe de proyecto local empleos',
#  'Director de publicidad empleos',
#  'Gerente de control empleos',
#  'Delineante empleos',
#  'Director ejecutivo de cuentas empleos',
#  'Psic\xc3\xb3logo cl\xc3\xadnico especializado en salud mental empleos',
#  'Ejecutivo responsable del equipo de protecci\xc3\xb3n de activos empleos',
#  'Ilustrador creativo empleos',
#  'Jefe de redacci\xc3\xb3n empleos',
#  'T\xc3\xa9cnico de oftalmolog\xc3\xada empleos',
#  'Jefe de proyecto de inteligencia empresarial empleos',
#  'Director de equipo empleos',
#  'Consultor de seguridad empleos',
#  'Funcionario de libertad condicional empleos',
#  'Jefe de ventas de banquetes empleos',
#  'Oficial ejecutivo empleos',
#  'Director comercial empleos',
#  'Dise\xc3\xb1ador gr\xc3\xa1fico en pr\xc3\xa1cticas empleos',
#  'Becario del departamento creativo empleos',
#  'Director de donaciones planificadas empleos',
#  'Desarrollador superior de Java empleos',
#  'Analista de estad\xc3\xadsticas empleos',
#  'Consejero de salud empleos',
#  'Analista superior de redes empleos',
#  'Supervisor de secci\xc3\xb3n empleos',
#  'Director de ingenier\xc3\xada de fiabilidad empleos',
#  'Asesor de pol\xc3\xadticas educativas empleos',
#  'Ventas de renta variable empleos',
#  'Director de ventas de cuentas globales empleos',
#  'Contable de clientes empleos',
#  'Director de requisitos empleos',
#  'T\xc3\xa9cnico del laboratorio de desarrollo e investigaci\xc3\xb3n empleos',
#  'Estudiante de Empresariales empleos',
#  'Consultor de sistemas y aplicaciones empleos',
#  'Director de d\xc3\xada empleos',
#  'Ejecutivo de investigaci\xc3\xb3n de mercados empleos',
#  'Profesor de inform\xc3\xa1tica empleos',
#  'Jefe de entrega de productos empleos',
#  'Director de ventas del sector p\xc3\xbablico empleos',
#  'Supervisor deportivo empleos',
#  'Director de centro universitario empleos',
#  'Director de SAP Basis empleos',
#  'Banquero preferente empleos',
#  'Representante de gesti\xc3\xb3n de la calidad empleos',
#  'Administrador de relaciones gubernamentales empleos',
#  'T\xc3\xa9cnico de redes inform\xc3\xa1ticas empleos',
#  'Encargado de calidad de informaci\xc3\xb3n empleos',
#  'Coordinador de materiales empleos',
#  'Vendedor t\xc3\xa9cnico empleos',
#  'Especialista en asuntos normativos empleos',
#  'Jefe del equipo creativo empleos',
#  'Jefe de categor\xc3\xada global empleos',
#  'Gerente de comunicaci\xc3\xb3n empleos',
#  'Director de instalaci\xc3\xb3n empleos',
#  'Consultor de Remedy empleos',
#  'Instructor automovil\xc3\xadstico empleos',
#  'Ingeniero de comunicaciones empleos',
#  'Director de comunicaciones digitales empleos',
#  'Director global de cadena de suministro empleos',
#  'Nutricionista certificado empleos',
#  'Director regional de cuentas empleos',
#  'Director de ingenier\xc3\xada de soluciones empleos',
#  'Actuaci\xc3\xb3n societaria empleos',
#  'Instructor asociado empleos',
#  'Asistente de direcci\xc3\xb3n empleos',
#  'Director de cuentas de medios de comunicaci\xc3\xb3n empleos',
#  'Redactor de desarrollo empleos',
#  'Coordinador de validaci\xc3\xb3n empleos',
#  'Personal financiero en pr\xc3\xa1cticas empleos',
#  'Ingeniero jefe superior empleos',
#  'Secretario administrativo empleos',
#  'T\xc3\xa9cnico de integraci\xc3\xb3n empleos',
#  'Jefe de proyectos empleos',
#  'Probador de productos empleos',
#  'Ingeniero de usabilidad empleos',
#  'Arque\xc3\xb3logo empleos',
#  'Ingeniero de programaci\xc3\xb3n empleos',
#  'Capell\xc3\xa1n auxiliar empleos',
#  'Encargado de cumplimiento normativo empleos',
#  'M\xc3\xbasico empleos',
#  'Administrador de clientes empleos',
#  'M\xc3\xa9dico en pr\xc3\xa1cticas empleos',
#  'Asociado de laboratorio empleos',
#  'Asesor legislativo empleos',
#  'Asistente ejecutivo del consejero delegado empleos',
#  'Responsable principal de supervisi\xc3\xb3n empleos',
#  'Responsable del equipo de servicio t\xc3\xa9cnico empleos',
#  'Controlador de ventas empleos',
#  'Coach de \xc3\xa9xito personal empleos',
#  'Administrador de datos de proyectos empleos',
#  'Recepcionista empleos',
#  'Director de arquitectura de sistemas empleos',
#  'Director de cuentas de programas empleos',
#  'Cient\xc3\xadfico de aseguramiento de la calidad empleos',
#  'Ingeniero de maquinaria empleos',
#  'Director comercial empleos',
#  'Analista de datos comerciales empleos',
#  'Arquitecto jefe de proyecto empleos',
#  'Finanzas de empresa empleos',
#  'Camionero empleos',
#  'Jefe de remuneraci\xc3\xb3n y prestaciones empleos',
#  'Director de asociaciones empleos',
#  'Director jefe de programa empleos',
#  'Analista de interfaz empleos',
#  'Profesor universitario invitado empleos',
#  'Auxiliar de adquisici\xc3\xb3n empleos',
#  'Productor ejecutivo empleos',
#  'Servicio t\xc3\xa9cnico al cliente empleos',
#  'Auxiliar administrativo empleos',
#  'Asistente personal del director general empleos',
#  'Jefe de zona de ventas empleos',
#  'Analista fiscal empleos',
#  'Jefe de redacci\xc3\xb3n m\xc3\xa9dica empleos',
#  'Defensor del Pueblo empleos',
#  'Analista de presupuestos empleos',
#  'T\xc3\xa9cnico de construcci\xc3\xb3n empleos',
#  'Especialista en recuperaci\xc3\xb3n ante desastres empleos',
#  'Responsable de equipo de infraestructuras empleos',
#  'Director de servicios de productos empleos',
#  'Montador mec\xc3\xa1nico empleos',
#  'Secretario de departamento empleos',
#  'Consultor superior de servicios empleos',
#  'Productor de medios audiovisuales empleos',
#  'Consultor de marketing digital empleos',
#  'Director de ventas de cuentas estrat\xc3\xa9gicas empleos',
#  'Becario de dise\xc3\xb1o de interacci\xc3\xb3n empleos',
#  'Socio empleos',
#  'Director de marketing interactivo empleos',
#  'Consultor de finanzas personales empleos',
#  'Controlador a\xc3\xa9reo empleos',
#  'Redactor de becas empleos',
#  'Encargado de producci\xc3\xb3n empleos',
#  'T\xc3\xa9cnico auxiliar de selecci\xc3\xb3n de personal empleos',
#  'Responsable del equipo de planificaci\xc3\xb3n empleos',
#  'Analista de mercado de materias primas empleos',
#  'Analista de banca privada empleos',
#  'Ejecutivo de recepci\xc3\xb3n empleos',
#  'Controlador de presupuestos empleos',
#  'B\xc3\xbasqueda de recursos de selecci\xc3\xb3n de personal empleos',
#  'Agente de puesto fronterizo empleos',
#  'Responsable de proyectos de ventas empleos',
#  'Jefe de control de planificaci\xc3\xb3n empleos',
#  'Analista de sistemas de operaciones empleos',
#  'Gesti\xc3\xb3n de recursos empleos',
#  'Director de informaci\xc3\xb3n m\xc3\xa9dica empleos',
#  'Director principal de investigaci\xc3\xb3n empleos',
#  'Ingeniero de dise\xc3\xb1o anal\xc3\xb3gico empleos',
#  'Jefe del equipo operaciones empleos',
#  'Controlador de planificaci\xc3\xb3n de materiales empleos',
#  'Jefe de servicios financieros empleos',
#  'Kinesi\xc3\xb3logo empleos',
#  'Director de gesti\xc3\xb3n del ciclo de vida de los productos empleos',
#  'Estudiante universitario empleos',
#  'Jefe de env\xc3\xados empleos',
#  'Jefe de primera l\xc3\xadnea empleos',
#  'Dise\xc3\xb1ador floral empleos',
#  'Ingeniero de radio empleos',
#  'Ayudante de producci\xc3\xb3n empleos',
#  'Subdirector de desarrollo comunitario empleos',
#  'Dise\xc3\xb1o gr\xc3\xa1fico de preprensa empleos',
#  'Maestro auxiliar empleos',
#  'Director de marketing interactivo empleos',
#  'Coordinador de formaci\xc3\xb3n de TI empleos',
#  'Entrenador certificado empleos',
#  'Director de seguridad empleos',
#  'Profesor universitario investigador adjunto empleos',
#  'Asesor superior empleos',
#  'Director de proyectos de almac\xc3\xa9n de datos empleos',
#  'Enfermero practicante de familia empleos',
#  'Representante de ventas externas empleos',
#  'Especialista en ventas de productos sanitarios empleos',
#  'Jefe de implementaci\xc3\xb3n para clientes empleos',
#  'Jefe de operaciones estrat\xc3\xa9gicas empleos',
#  'Director de servicios de marketing empleos',
#  'Artista t\xc3\xa9cnico empleos',
#  'Director de servicios de proyectos empleos',
#  'Director de inmuebles empleos',
#  'Director de proyectos de desarrollo comercial empleos',
#  'Vicepresidente de financiaci\xc3\xb3n de proyectos empleos',
#  'Director de proyectos de producci\xc3\xb3n empleos',
#  'Auxiliar de equipo empleos',
#  'Ingeniero de Java empleos',
#  'T\xc3\xa9cnico de an\xc3\xa1lisis de errores empleos',
#  'Servicio de ventas al cliente empleos',
#  'Responsable de SSM empleos',
#  'Vicepresidente de investigaci\xc3\xb3n de marketing empleos',
#  'Especialista en formaci\xc3\xb3n t\xc3\xa9cnica empleos',
#  'Jefe comercial empleos',
#  'Director nacional de marketing comercial empleos',
#  'Pastor del campus empleos',
#  'Responsable de log\xc3\xadstica empleos',
#  'Estudiante aprendiz empleos',
#  'Coordinador de gesti\xc3\xb3n de datos empleos',
#  'Profesor adjunto empleos',
#  'Especialista en fitness empleos',
#  'Gerente de servicios de asesor\xc3\xada empleos',
#  'Director de proyectos de recursos humanos empleos',
#  'Director principal nacional de cuentas empleos',
#  'Jefe de tecnolog\xc3\xada empleos',
#  'Jefe de proyectos de investigaci\xc3\xb3n empleos',
#  'T\xc3\xa9cnico de salud del comportamiento empleos',
#  'Director de cumplimiento normativo empleos',
#  'Coordinador editorial empleos',
#  'Director ejecutivo asistente empleos',
#  'Director de fondos empleos',
#  'Asociado inmobiliario empleos',
#  'Mec\xc3\xa1nico de motores empleos',
#  'Director de higiene de los alimentos empleos',
#  'Vicepresidente de prestaci\xc3\xb3n de servicios empleos',
#  'Desarrollador de software de prueba empleos',
#  'Gerente de recaudaci\xc3\xb3n empleos',
#  'Especialista en redes de PC empleos',
#  'Arquitecto de infraestructuras de TI empleos',
#  'Analista de sistemas de software empleos',
#  'Coordinador empleos',
#  'Personal de tecnolog\xc3\xada de la informaci\xc3\xb3n empleos',
#  'Soporte de campo empleos',
#  'Asesor jefe empleos',
#  'Ingeniero de campo de Premier empleos',
#  'Auxiliar de gesti\xc3\xb3n de recursos humanos empleos',
#  'Gerente superior de cuentas empleos',
#  'M\xc3\xa9dico especialista empleos',
#  'Seguridad (polic\xc3\xada) empleos',
#  'Controlador t\xc3\xa9cnico empleos',
#  'Jefe auxiliar de proyecto empleos',
#  'Coordinador de escuela empleos',
#  'Jefe de seguridad medioambiental empleos',
#  'Analista de gesti\xc3\xb3n de servicios empleos',
#  'Asesor cl\xc3\xadnico empleos',
#  'Director de datos cl\xc3\xadnicos empleos',
#  'Oficial de abastecimiento empleos',
#  'Supervisor de aseguramiento de la calidad empleos',
#  'Director de proyectos de TI empleos',
#  'Mec\xc3\xa1nico electr\xc3\xb3nico empleos',
#  'Director de proyectos de desarrollo empresarial empleos',
#  'Coordinador de producci\xc3\xb3n de marketing empleos',
#  'Ejecutivo de documentaci\xc3\xb3n empleos',
#  'Artista jefe empleos',
#  'Director educativo empleos',
#  'Consultor de sala de exposici\xc3\xb3n empleos',
#  'Becario de administraci\xc3\xb3n de empresa empleos',
#  'Director de cuentas estrat\xc3\xa9gicas empleos',
#  'Agente del cierre empleos',
#  'Director de ventas de publicidad empleos',
#  'Director del equipo de bienes inmuebles empleos',
#  'Orientador de estudiantes empleos',
#  'Director del sistema inform\xc3\xa1tico de RR. HH. empleos',
#  'Modelo y actriz empleos',
#  'Becario de producci\xc3\xb3n de v\xc3\xaddeo empleos',
#  'Administrador de Linux empleos',
#  'Coordinador de asuntos estudiantiles empleos',
#  'Terapeuta del comportamiento empleos',
#  'Consultor de multimedia empleos',
#  'Director de env\xc3\xados empleos',
#  'Operador de renta variable empleos',
#  'Especialista en control de procesos empleos',
#  'Auxiliar de ventas de publicidad empleos',
#  'Redactor t\xc3\xa9cnico empleos',
#  'Asociado de campo empleos',
#  'Asesor de relaciones empleos',
#  'Coordinador de evaluaci\xc3\xb3n empleos',
#  'Representante del sistema de ventas empleos',
#  'Estudiante de Derecho en pr\xc3\xa1cticas empleos',
#  'Gerente financiero y administrativo empleos',
#  'T\xc3\xa9cnico de laboratorio empleos',
#  'Instructor de voz empleos',
#  'Consultor de soporte de software empleos',
#  'Asociado m\xc3\xa9dico empleos',
#  'Consultor de aseguramiento de la calidad del software empleos',
#  'Director de marketing de arrendamientos empleos',
#  'Especialista de servicio cl\xc3\xadnico empleos',
#  'Conductor de carretera empleos',
#  'Vicepresidente de ventas y marketing empleos',
#  'Auxiliar administrativo contable empleos',
#  'Director de planificaci\xc3\xb3n de negocio empleos',
#  'Vicepresidente de riesgos empleos',
#  'Subsecretario ejecutivo empleos',
#  'Analista de activos empleos',
#  'Administrador de asociaciones de empresa empleos',
#  'Especialista en publicaciones empleos',
#  'Profesor de ingl\xc3\xa9s y periodismo empleos',
#  'Estudiante cl\xc3\xadnico empleos',
#  'Residente de medicina interna empleos',
#  'Gerente del centro de TI empleos',
#  'Ingeniero de Java y Java EE empleos',
#  'Coordinador de desarrollo organizativo empleos',
#  'Bioqu\xc3\xadmico empleos',
#  'Ejecutivo de servicio empleos',
#  'Vicepresidente principal ejecutivo empleos',
#  'Departamento de relaciones p\xc3\xbablicas empleos',
#  'Administrador de Internet empleos',
#  'Consultor de SAP SD empleos',
#  'Coordinador de itinerancia empleos',
#  'Gerente empresarial ejecutivo empleos',
#  'Ejecutivo de log\xc3\xadstica empleos',
#  'Auxiliar administrativo jur\xc3\xaddico empleos',
#  'Especialista en productos de informaci\xc3\xb3n empleos',
#  'Responsable de excelencia operativa empleos',
#  'Director de educaci\xc3\xb3n m\xc3\xa9dica empleos',
#  'Becario de gesti\xc3\xb3n de producto empleos',
#  'Ingeniero de estructuras empleos',
#  'Presidente del Consejo de Administraci\xc3\xb3n empleos',
#  'Constructor de empresas empleos',
#  'Profesor de japon\xc3\xa9s empleos',
#  'Piloto aeronaval empleos',
#  'Oficial de artiller\xc3\xada de campa\xc3\xb1a empleos',
#  'Director de fiscalidad empleos',
#  'Jefe de lavander\xc3\xada empleos',
#  'Becario de medios de comunicaci\xc3\xb3n y relaciones p\xc3\xbablicas empleos',
#  'Analista de cambio empresarial empleos',
#  'Analista adjunto de empresa empleos',
#  'Comercial t\xc3\xa9cnico empleos',
#  'Farmac\xc3\xa9utico de asuntos normativos empleos',
#  'Gerente superior de venta minorista empleos',
#  'Asesor de medios digitales empleos',
#  'Desarrollador de Dynamics empleos',
#  'Consejero gerente empleos',
#  'Operador de cinta empleos',
#  'Responsable administrativo de finanzas empleos',
#  'Coordinador de servicios al paciente empleos',
#  'Enfermero de cuidados intensivos empleos',
#  'Profesor de lengua extranjera empleos',
#  'Transici\xc3\xb3n empleos',
#  'Contratista independiente empleos',
#  'Especialista en pr\xc3\xa9stamos empleos',
#  'Auxiliar de transporte empleos',
#  'Director de marketing de canal empleos',
#  'Ventas al extranjero empleos',
#  'Supervisor de soporte de sistemas empleos',
#  'Auxiliar administrativo y de investigaci\xc3\xb3n empleos',
#  'Jefe comercial empleos',
#  'Coordinador de marketing web empleos',
#  'Operador de servicios empleos',
#  'Abogado infantil empleos',
#  'Ingeniero s\xc3\xa9nior empleos',
#  'Ingeniero de soluciones t\xc3\xa9cnicas empleos',
#  'Especialista en pr\xc3\xa9stamos comerciales empleos',
#  'Colaborador legislativo empleos',
#  'Asesor de comunidad empleos',
#  'Director de aplicaciones de Oracle empleos',
#  'Vicepresidente de estrategia del producto empleos',
#  'Relaciones con antiguos alumnos empleos',
#  'Especialista en hipotecas itinerante empleos',
#  'Generalista empleos',
#  'Ingeniero de sistemas de infraestructuras empleos',
#  'Director de desarrollo de productos de ventas empleos',
#  'Desarrollador de intercambio electr\xc3\xb3nico de datos empleos',
#  'Responsable de \xc3\xa1rboles empleos',
#  'T\xc3\xa9cnico asociado empleos',
#  'Consultor digital empleos',
#  'Trabajador de tesis empleos',
#  'Director de relaciones p\xc3\xbablicas con los medios empleos',
#  'Redactor publicitario creativo empleos',
#  'Jefe del equipo t\xc3\xa9cnico empleos',
#  'Representante de atenci\xc3\xb3n al cliente empleos',
#  'Asistente del consejero delegado empleos',
#  'Analista de planificaci\xc3\xb3n de redes empleos',
#  'Coordinador de operaciones de venta empleos',
#  'Asesor de atenci\xc3\xb3n primaria empleos']

# %%
len(keywords)
# Out:
# 199

# %%
mydataframe
# Out:
#        id                                     search_keyword volume location  \
# 0   12005                consultor de tecnología sap empleos      0    es_ES
# 0   21391                      director de nutrición empleos      0    es_ES
# 0    6914          director de servicios compartidos empleos      0    es_ES
# 0   10484  vicepresidente de desarrollo de operaciones em...      0    es_ES
# 0    5139                             director de rf empleos      0    es_ES
# 0    8904                                 comandante empleos      0    es_ES
# 0   21327          director de proyectos de hardware empleos      0    es_ES
# 0   11928                especialista cardiovascular empleos      0    es_ES
# 0   13983           jefe de ejecución de operaciones empleos      0    es_ES
# 0     593                                     mentor empleos      0    es_ES
# 0   12571     coordinador de prestación de servicios empleos      0    es_ES
# 0    3165            director general de inversiones empleos      0    es_ES
# 0    5095                    gerente de especialidad empleos      0    es_ES
# 0    1121                 especialista en desarrollo empleos      0    es_ES
# 0   19946                 jefe profesional de tienda empleos      0    es_ES
# 0   11721                             jefe de fletes empleos      0    es_ES
# 0    2877            ingeniero de puesta en servicio empleos      0    es_ES
# 0     553                     administrador de datos empleos      0    es_ES
# 0    3014                         supervisor clínico empleos      0    es_ES
# 0    5748         ejecutivo de asistencia al cliente empleos      0    es_ES
# 0    3584                gerente general de finanzas empleos      0    es_ES
# 0    4984                    arquitecto técnico jefe empleos      0    es_ES
# 0   21197           gerente de soporte técnico de ti empleos      0    es_ES
# 0    7916                         jefe de fiscalidad empleos      0    es_ES
# 0   12990                       director de hardware empleos      0    es_ES
# 0    4327                          consultor de java empleos      0    es_ES
# 0   18789                    recaudador de impuestos empleos      0    es_ES
# 0   15723   jefe de cadena de suministro de clientes empleos      0    es_ES
# 0   20501               operador de protección civil empleos      0    es_ES
# 0    6136                           decano académico empleos      0    es_ES
# ..    ...                                                ...    ...      ...
# 0     339                      analista de capitales empleos      0    es_ES
# 0     437                           comercial médico empleos      0    es_ES
# 0     255                    coordinador de campañas empleos      0    es_ES
# 0     244          experto en finanzas empresariales empleos      0    es_ES
# 0     436                       representante médico empleos     10    es_ES
# 0     445             diseñador de gráficos animados empleos      0    es_ES
# 0     538                             experto fiscal empleos      0    es_ES
# 0     283           experto en cumplimiento jurídico empleos      0    es_ES
# 0     326                  controlador de documentos empleos      0    es_ES
# 0     513  asesor de sistemas de información aplicados a ...      0    es_ES
# 0     317                                   dietista empleos     20    es_ES
# 0     412                     técnico de laboratorio empleos     30    es_ES
# 0     392                    encargado de innovación empleos      0    es_ES
# 0     288                                     asesor empleos     10    es_ES
# 0     452                experto en marketing online empleos      0    es_ES
# 0     351                       equipo de producción empleos      0    es_ES
# 0     410                  investigador postdoctoral empleos      0    es_ES
# 0     409                                 periodista empleos     70    es_ES
# 0     347                          comercial federal empleos      0    es_ES
# 0     404            gestor de carteras de inversión empleos      0    es_ES
# 0     470                         experto en precios empleos      0    es_ES
# 0     476                 desarrollador de productos empleos      0    es_ES
# 0     407                  desarrollador de software empleos     10    es_ES
# 0     201                     artista de gráficos 3d empleos      0    es_ES
# 0     276         ejecutivo de préstamos comerciales empleos      0    es_ES
# 0     397                    diseñador de interiores empleos     10    es_ES
# 0     377                       profesional del ocio empleos      0    es_ES
# 0     238  investigador en medicina y ciencias biológicas...      0    es_ES
# 0     508                         gestor de ingresos empleos      0    es_ES
# 0     234                         consultor bancario empleos      0    es_ES
#
#                                               keyword
# 0                         Consultor de tecnología SAP
# 0                               Director de nutrición
# 0                   Director de servicios compartidos
# 0   Vicepresidente de desarrollo de operaciones em...
# 0                                      Director de RF
# 0                                          Comandante
# 0                   Director de proyectos de hardware
# 0                         Especialista cardiovascular
# 0                    Jefe de ejecución de operaciones
# 0                                              Mentor
# 0              Coordinador de prestación de servicios
# 0                     Director general de inversiones
# 0                             Gerente de especialidad
# 0                          Especialista en desarrollo
# 0                          Jefe profesional de tienda
# 0                                      Jefe de fletes
# 0                     Ingeniero de puesta en servicio
# 0                              Administrador de datos
# 0                                  Supervisor clínico
# 0                  Ejecutivo de asistencia al cliente
# 0                         Gerente general de finanzas
# 0                             Arquitecto técnico jefe
# 0                    Gerente de soporte técnico de TI
# 0                                  Jefe de fiscalidad
# 0                                Director de hardware
# 0                                   Consultor de Java
# 0                             Recaudador de impuestos
# 0            Jefe de cadena de suministro de clientes
# 0                        Operador de protección civil
# 0                                    Decano académico
# ..                                                ...
# 0                               Analista de capitales
# 0                                    Comercial médico
# 0                             Coordinador de campañas
# 0                   Experto en finanzas empresariales
# 0                                Representante médico
# 0                      Diseñador de gráficos animados
# 0                                     Experto fiscal
# 0                    Experto en cumplimiento jurídico
# 0                           Controlador de documentos
# 0   Asesor de sistemas de información aplicados a ...
# 0                                            Dietista
# 0                              Técnico de laboratorio
# 0                             Encargado de innovación
# 0                                              Asesor
# 0                         Experto en marketing online
# 0                                Equipo de producción
# 0                           Investigador postdoctoral
# 0                                          Periodista
# 0                                   Comercial federal
# 0                     Gestor de carteras de inversión
# 0                                  Experto en precios
# 0                          Desarrollador de productos
# 0                           Desarrollador de software
# 0                              Artista de gráficos 3D
# 0                  Ejecutivo de préstamos comerciales
# 0                             Diseñador de interiores
# 0                                Profesional del ocio
# 0      Investigador en medicina y ciencias biológicas
# 0                                  Gestor de ingresos
# 0                                  Consultor bancario
#
# [18810 rows x 5 columns]

# %%
keyword_list
# Out:
# -----------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-203-28d698b4b54a> in <module>()
# ----> 1 keyword_list
#
# NameError: name 'keyword_list' is not defined

# %%
mydataframe
# Out:
# Empty DataFrame
# Columns: [id, search_keyword, volume, location, keyword]
# Index: []

# %%
mydataframe = mydataframe.dropna();
write_dataframe(client, '/user/luzhang/career_page_seo/google/volume/results.avro', mydataframe, overwrite = True, schema = schema);

# %%
a = 3

# %%
a += 1

# %%
a
# Out:
# 4

# %%
1300 % 700
# Out:
# 600

# %%
0 % 700
# Out:
# 0

# %%
raise Exception('ugh')

# %%
if __name__ == '__main__':
    """Driver for google ads API requests, version 1"""
    
    #initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage();

    #initialize pandas dataframe
    mydataframe = pd.DataFrame(columns = pandas_schema);

    #for i in range(len(df3)):
    for i in range(2):
        
        keyword_dict      = df3.iloc[i]['names'];
        myid              = df3.iloc[i]['id']
        search_keywords   = build_search_keywords(keyword_dict);
        google_api_result = []
        
        
        country_codes = country_mappings[country]
        
        for i in search_keywords:
            google_api_result += main(adwords_client, [i], country_codes)
        
        mydataframe = add_to_dataframe(google_api_result, keyword_dict, myid, country, mydataframe)
        time.sleep(2)
